# %%
import docx
import json
import math
from datetime import datetime
import time
from urllib import request
#from django.http import HttpResponse  
import pandas as pd
import numpy as np

# %%
#get text and Header from docx file, return dic
def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    result = {}
    Header = ""
    content =[]    
    for para in doc.paragraphs:
        fullText.append(para.text)
        if para.style.name.startswith('Heading'):
            if Header != para.text:
                #print("Header:"+Header)
                #print("New Header:"+para.text)
                #print("Cotenct:"+"\n".join(content))
                if Header!="":
                    #result[Header]="\n".join(content)
                    result[Header]="\n".join(content)
                    content =[]
                Header = para.text
            else:
                Header=para.text
                print(para.text)
        else:
            content.append(para.text)
    return result

# %%
kk=getText('C:\\N-21AJPF420V37-Data\\w22810\\Downloads\\CB009858 CFAM 20230707.docx')

# %%
kk["2.1.3.1.1.1.1.1.2 US_CB009858-F#E1: vDU startup exception handling for Multiple RAN-NIC and N+ (AHM & UP) Pod deployment "]
# Out:
# 'Description: This user scenario (US) covers exception handling at vDU startup for Multiple RAN-NIC and N+ (AHM & UP) Pod deployment. CB009858 US covers SNO vDU D-RAN configuration with multiple RAN-NIC and N+ (AHM & UP) pod.  \nActors: OAM, L1SW, L1PF, RCP, Deployment, SCM, Operator/SyVe/I&V, RU(AHCA)\nPrecondition:\nUS_CB009858-F#B1 user scenario followed until step-5\n\nProcedure:\n1.\t‘Startup timer’ maintained by OAM expires. OAM discovers some/all AHM and/or UP pods have NOT reached ‘readiness’ state.\n2.\tScenario-1\na.\tMinimum available L1-AHM(pod)-UP(pod) instance has not reached readiness state\nb.\tOAM shall raise on, Fault 4350 and corresponding alarm 7101 shall be posted with Critical severity with recovery=vDU reset\n3.\tScenario-2\na.\tOAM has unblocked site commissioning procedure after minimum available L1-AHM(pod)-UP(pod) instance readiness had reached\nb.\tFor failed N+ pod, OAM shall raise, Fault 4350 and corresponding alarm 7115 with Minor severity\nc.\tOAM shal
# ...

# %%
kk['1.1.1 Version History']
# Out:
# ['Requirement ID :  ',
#  'Requirement Type :  ',
#  'Object Type :  ',
#  '- Description :  ',
#  '- Parameter Description :  ',
#  '- Parameter Details :  ',
#  '- Parameter References :  ',
#  'Release :  ',
#  '- Parameter Values :  ',
#  '- SFS Info :  ',
#  'Requirement Version :  ',
#  'Change History :  ',
#  'Priority :  ',
#  'NE List (DXL) :  ',
#  'NE List :  ',
#  'System Release (DXL) :  ',
#  'RAT Features (DXL) :  ',
#  'CR + Pronto (DXL) :  ',
#  'Feature Info (DXL) :  ',
#  'LTE releases (DXL) :  ',
#  'Other Releases :  ',
#  'Phase :  ',
#  'Status :  ',
#  'BTS Release (Flexi) (DXL) :  ',
#  'CR Info (DXL) :  ',
#  'Specified CN/Pronto (DXL) :  ',
#  'eNb activation info (DXL) :  ',
#  'Architectural Element (DXL) :  ',
#  'TDD Release :  ',
#  'TDD Feature Info (DXL) :  ',
#  'Validity :  ',
#  'Technical Area :  ',
#  'Additional information :  ',
#  'Rationale :  ',
#  'Product :  ',
#  'HW-SW Package (DXL) :  ',
#  'Acceptance Criteria :  ',
# ...

# %%
for i in kk.keys():
    print(i)
# Out:
# 1 Feature Analysis
# 1.1 Introduction
# 1.1.1 Version History
# 1.1.2 Feature Overview
# 1.1.3 Open Issues
# 1.1.4 Decisions
# 1.1.5 CFAM Contributors
# 1.1.5.1 SFS Authors
# 1.1.5.2 Other CFAM contacts
# 1.1.6 Terms and Abbreviations
# 1.1.7 References
# 1.1.8 3GPP Baseline
# 1.2 System (RAN) Level User Stories (from FS2 Material)
# 1.2.1 System Level User Stories from DOORS Stakeholder Requirements Module
# 1.2.1.1 CB009858 Loki RAN NIC for vDU - HW Introduction and L3 call with FDD and TDD+TDD
# 1.2.1.1.1 Items from module: /NET Common Modules/Stakeholder Requirements/Stakeholder Requirements
# 1.2.1.1.1.1 5G
# 1.2.1.1.1.1.1 5G gNB
# 1.2.1.1.1.1.1.1 CB009858 Loki RAN NIC for vDU - HW Introduction and L3 call with FDD and TDD+TDD
# 1.2.2 Additional System Level User Stories (Edited Here)
# 1.3 System Level Feature Description
# 1.3.1 Feature Scope
# 1.3.1.1 CB009858-A
# 1.3.1.2 CB009858-B L3 Call Cabling and Connectivity
# 1.3.1.3 CB009858-C
# ...

# %%
pd_doc = pd.DataFrame(kk.items(),columns=['Header', 'Content'])

# %%
pd_doc
# Out:
#                                                 Header  \
# 0                                   1 Feature Analysis
# 1                                     1.1 Introduction
# 2                                1.1.1 Version History
# 3                               1.1.2 Feature Overview
# 4                                    1.1.3 Open Issues
# ..                                                 ...
# 573                                     7.9 Check List
# 574                      8 Feature Detailed NMS design
# 575                  8.1 Entity Component Requirements
# 576  8.2 Version History of the Chapter Detailed NM...
# 577                                   8.3 <subsection>
#
#                                                Content
# 0    ID :  CB009858-1\nInformation in this formal m...
# 1    Requirement ID :  \nRequirement Type :  \nObje...
# 2    Requirement ID :  \nRequirement Type :  \nObje...
# 3    Requirement ID :  \nRequirement Type :  \nObje...
# ...

# %%
pd_doc[pd_doc["Header"]=="2.2.2 CB009858-F TDD+TDD L3 call on OE22 2U with two RAN-NIC"]['Content']
# Out:
# 121    Requirement ID :  \nRequirement Type :  \nObje...
# Name: Content, dtype: object

# %%
kk
# Out:
# {'1 Feature Analysis': 'ID :  CB009858-1\nInformation in this formal module is confidential.\nInformation that shall be shared only with specific individuals or groups on a "need-to-know" basis. The information / data owner must determine which individuals or groups the principle applies to.\nRequirement ID :  \nRequirement Type :  \nObject Type :  \n- Description :  \n- Parameter Description :  \n- Parameter Details :  \n- Parameter References :  \nRelease :  \n- Parameter Values :  \n- SFS Info :  \nRequirement Version :  \nChange History :  \nPriority :  \nNE List (DXL) :  \nNE List :  \nSystem Release (DXL) :  \nRAT Features (DXL) :  \nCR + Pronto (DXL) :  \nFeature Info (DXL) :  \nLTE releases (DXL) :  \nOther Releases :  \nPhase :  \nStatus :  \nBTS Release (Flexi) (DXL) :  \nCR Info (DXL) :  \nSpecified CN/Pronto (DXL) :  \neNb activation info (DXL) :  \nArchitectural Element (DXL) :  \nTDD Release :  \nTDD Feature Info (DXL) :  \nValidity :  \nTechnical Area :  \nAdditional i
# ...
